# %% [markdown]
# <a href="https://colab.research.google.com/github/Mudit1234Sinha/NLP-Part-1/blob/main/PyCaret_NLP_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
from pycaret.utils import enable_colab
enable_colab()
# Out:
# Colab mode enabled.

# %%
from pycaret.datasets import get_data
data = get_data('kiva')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#               country  ... status
# 0  Dominican Republic  ...      0
# 1  Dominican Republic  ...      0
# 2  Dominican Republic  ...      0
# 3  Dominican Republic  ...      0
# 4  Dominican Republic  ...      0
#
# [5 rows x 7 columns]

# %%
data.shape
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (6818, 7)

# %%
data1 = data.sample(1000, random_state=786).reset_index(drop=True)
data1.shape
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# (1000, 7)

# %%
from pycaret.nlp import *
exp_nlp101 = setup(data=data1, target='en', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                                 <td id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002row1_col0" class="data row1 col0" >Documents</td>
#                         <td id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002row1_col1" class="data row1 col1" >1000</td>
#             </tr>
#             <tr>
#                                 <td id="T_708125bc_5ef9_11eb_90ac_0242ac1c0002row2_col0" class="data row2 col0" >Vocab Size</td>
# ...

# %%
lda = create_model('lda')

# %%
print(lda)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# LdaModel(num_terms=4573, num_topics=4, decay=0.5, chunksize=100)

# %%
lda_results = assign_model(lda)
lda_results.head()
# Out:
#               country  ... Perc_Dominant_Topic
# 0               Kenya  ...                0.99
# 1               Kenya  ...                0.56
# 2  Dominican Republic  ...                0.78
# 3               Kenya  ...                0.92
# 4               Kenya  ...                0.87
#
# [5 rows x 13 columns]

# %%
plot_model()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
# ...

# %%
plot_model(plot = 'bigram')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
# ...

# %%
plot_model(lda, plot= 'topic_distribution')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
# ...

# %%
plot_model(lda, plot='umap')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
evaluate_model(lda)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
save_model(lda, 'LDA Model')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Model Succesfully Saved
# (<gensim.models.ldamodel.LdaModel at 0x7f542d480d68>, 'LDA Model.pkl')
